# %%
# %matplotlib ipympl
import parse_tvd
from pathlib import Path
import numpy as np

# %%
if __name__ == "__main__":
    file_path = Path("Si+gold.tvd")
    data = parse_tvd.read_tvd_files(file_path)
    parse_tvd.plot_file_coordinates(data)
    reference = None
    reference = data[0]
    reference[1] = reference[1]/np.max(reference[1])
    section = data[50]
    section[1] = section[1]/np.max(section[1])
    parse_tvd.plot_response(section, reference=reference)
# Out:
# INFO:root:Total number of sections: 785
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Some detected floats in section:
# ```
# 34	146.4320000000007
# 35	0.0005
# 42	146.4320000000025
# 43	0.0005
# 51	0.0
# 52	0.0
# 53	0.0
# 54	0.0
# 55	0.0
# 71	-112053.12000000109
# 72	-8694.7134375
# 80	1550.2240624999995
# 88	0.0
# 96	1.1423569687500001e-10
# 97	128302096222.08374
# 101	-2.4830028610387703e-06
# 104	1.743125e-15
# ```
